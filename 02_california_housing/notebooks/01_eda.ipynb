# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %% [markdown]
# # description: load data using modular loader

# %%
from src.data_loader import load_data

df = load_data()
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %% [markdown]
# # description: univariate distributions

# %%
from src.visualization import plot_distribution

plot_distribution(df, "MedInc")
plot_distribution(df, "HouseAge")
plot_distribution(df, "MedHouseVal")

# %% [markdown]
# ## Insight
# MedInc:
# Median income is right-skewed.
# Most districts have moderate income levels.
#
# MedHouseVal:
# House prices are not normally distributed.
# The target variable is right-skewed.
#
# HouseAge:
# Some age values appear capped.

# %% [markdown]
# # description: correlation heatmap analysis

# %%
from src.visualization import plot_correlation

plot_correlation(df)

# %% [markdown]
# ## Insight
# Median income has the strongest positive correlation with house value.
# ##### 0 : Weak linear relationship
# ##### 1 & -1 : Strong relationship

# %% [markdown]
# # description: spatial distribution of housing prices

# %%
from src.visualization import plot_geography

plot_geography(df)

# %% [markdown]
# ## Insight
# Housing prices strongly depend on geographic location.
